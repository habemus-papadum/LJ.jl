# %%
using ImageShow, Metal, Colors, GeometryBasics, StaticArrays


# UI
function Base.show(io::IO, mime::MIME"image/png", img::MtlArray{C}) where C<:Colorant 
    Base.show(io, mime, Array(img))
end

function Base.showable(mime::MIME"image/png", img::MtlArray{C}) where C<:Colorant 
    true
end

# %%
# Our basic primitive
function generate(f, img)
    r, c = Int32.(size(img))
    i,j = thread_position_in_grid_2d()
    
    @inbounds if i <= r && j <= c
        @inline img[i,j] = eltype(img)(f(i,j,r,c))
    end
    return
end


simple(i,j,r,c) = colorant"thistle"
# Out:
# simple (generic function with 1 method)

# %%
n = 50
b = MtlArray{RGB{Float32}}(undef, n,n)
threads = 16
groups = cld.(n, threads)
@Metal.sync @metal threads=threads,threads groups=groups,groups generate(simple, b)
b
# Out:
# InvalidIRError: compiling MethodInstance for generate(::typeof(simple), ::MtlDeviceMatrix{RGB{Float32}, 1}) resulted in invalid LLVM IR
#
# Reason: unsupported dynamic function invocation (call to _eltypes_supported(::Type{<:Colorant}, ::Type{C}) where C<:Colorant @ ColorTypes ~/.julia/packages/ColorTypes/L7biZ/src/traits.jl:150)
#
# Stacktrace:
#
#  [1] _eltypes_supported
#
#    @ ~/.julia/packages/ColorTypes/L7biZ/src/traits.jl:150
#
#  [2] eltypes_supported
#
#    @ ~/.julia/packages/ColorTypes/L7biZ/src/traits.jl:148
#
#  [3] issupported
#
#    @ ~/.julia/packages/ColorTypes/L7biZ/src/traits.jl:160
#
#  [4] ccolor
#
#    @ ~/.julia/packages/ColorTypes/L7biZ/src/traits.jl:450
#
#  [5] convert
#
#    @ ~/.julia/packages/ColorTypes/L7biZ/src/conversions.jl:72
#
#  [6] _new_colorant
#
#    @ ~/.julia/packages/ColorTypes/L7biZ/src/types.jl:558
#
#  [7] Color
#
#    @ ~/.julia/packages/ColorTypes/L7biZ/src/types.jl:535
#
#  [8] generate
#
#    @ ~/src/LJ.jl/scratch/MetalPatterns/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W1sZmlsZQ==.jl:8
#
# Reason: unsupported call to an unknown function (call to jl_f_issubtype)
#
# Stacktrace:
#
#  [1] issupported
#
#    @ ~/.julia/packages/ColorTypes/L7biZ/src/traits.jl:160
#
#  [2] ccolor
#
#    @ ~/.julia/packages/ColorTypes/L7biZ/src/traits.jl:450
#
#  [3] convert
#
#    @ ~/.julia/packages/ColorTypes/L7biZ/src/conversions.jl:72
#
#  [4] _new_colorant
#
#    @ ~/.julia/packages/ColorTypes/L7biZ/src/types.jl:558
#
#  [5] Color
#
#    @ ~/.julia/packages/ColorTypes/L7biZ/src/types.jl:535
#
#  [6] generate
#
#    @ ~/src/LJ.jl/scratch/MetalPatterns/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W1sZmlsZQ==.jl:8
#
# Hint: catch this exception as `err` and call `code_typed(err; interactive = true)` to introspect the erronous code with Cthulhu.jl
#
#
#
# Stacktrace:
#
#   [1] check_ir(job::GPUCompiler.CompilerJob{GPUCompiler.MetalCompilerTarget, Metal.MetalCompilerParams}, args::LLVM.Module)
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/1cGqD/src/validation.jl:167
#
#   [2] macro expansion
#
#     @ ~/.julia/packages/GPUCompiler/1cGqD/src/driver.jl:383 [inlined]
#
#   [3] macro expansion
#
#     @ ~/.julia/packages/Tracy/GcShf/src/tracepoint.jl:158 [inlined]
#
#   [4] macro expansion
#
#     @ ~/.julia/packages/GPUCompiler/1cGqD/src/driver.jl:382 [inlined]
#
#   [5] emit_llvm(job::GPUCompiler.CompilerJob; kwargs::@Kwargs{})
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/1cGqD/src/utils.jl:116
#
#   [6] emit_llvm(job::GPUCompiler.CompilerJob)
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/1cGqD/src/utils.jl:114
#
#   [7] compile_unhooked(output::Symbol, job::GPUCompiler.CompilerJob; kwargs::@Kwargs{})
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/1cGqD/src/driver.jl:95
#
#   [8] compile_unhooked
#
#     @ ~/.julia/packages/GPUCompiler/1cGqD/src/driver.jl:80 [inlined]
#
#   [9] compile(target::Symbol, job::GPUCompiler.CompilerJob; kwargs::@Kwargs{})
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/1cGqD/src/driver.jl:67
#
#  [10] compile
#
#     @ ~/.julia/packages/GPUCompiler/1cGqD/src/driver.jl:55 [inlined]
#
#  [11] (::Metal.var"#157#165"{GPUCompiler.CompilerJob{GPUCompiler.MetalCompilerTarget, Metal.MetalCompilerParams}})(ctx::LLVM.Context)
#
#     @ Metal ~/.julia/packages/Metal/N2ABH/src/compiler/compilation.jl:108
#
#  [12] JuliaContext(f::Metal.var"#157#165"{GPUCompiler.CompilerJob{GPUCompiler.MetalCompilerTarget, Metal.MetalCompilerParams}}; kwargs::@Kwargs{})
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/1cGqD/src/driver.jl:34
#
#  [13] JuliaContext(f::Function)
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/1cGqD/src/driver.jl:25
#
#  [14] macro expansion
#
#     @ ~/.julia/packages/Metal/N2ABH/src/compiler/compilation.jl:107 [inlined]
#
#  [15] macro expansion
#
#     @ ~/.julia/packages/ObjectiveC/TgrW6/src/os.jl:264 [inlined]
#
#  [16] compile(job::GPUCompiler.CompilerJob)
#
#     @ Metal ~/.julia/packages/Metal/N2ABH/src/compiler/compilation.jl:105
#
#  [17] actual_compilation(cache::Dict{Any, Any}, src::Core.MethodInstance, world::UInt64, cfg::GPUCompiler.CompilerConfig{GPUCompiler.MetalCompilerTarget, Metal.MetalCompilerParams}, compiler::typeof(Metal.compile), linker::typeof(Metal.link))
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/1cGqD/src/execution.jl:245
#
#  [18] cached_compilation(cache::Dict{Any, Any}, src::Core.MethodInstance, cfg::GPUCompiler.CompilerConfig{GPUCompiler.MetalCompilerTarget, Metal.MetalCompilerParams}, compiler::Function, linker::Function)
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/1cGqD/src/execution.jl:159
#
#  [19] macro expansion
#
#     @ ~/.julia/packages/Metal/N2ABH/src/compiler/execution.jl:189 [inlined]
#
#  [20] macro expansion
#
#     @ ./lock.jl:273 [inlined]
#
#  [21] mtlfunction(f::typeof(generate), tt::Type{Tuple{typeof(simple), MtlDeviceMatrix{RGB{Float32}, 1}}}; name::Nothing, kwargs::@Kwargs{})
#
#     @ Metal ~/.julia/packages/Metal/N2ABH/src/compiler/execution.jl:184
#
#  [22] mtlfunction(f::typeof(generate), tt::Type{Tuple{typeof(simple), MtlDeviceMatrix{RGB{Float32}, 1}}})
#
#     @ Metal ~/.julia/packages/Metal/N2ABH/src/compiler/execution.jl:182
#
#  [23] macro expansion
#
#     @ ~/.julia/packages/Metal/N2ABH/src/compiler/execution.jl:85 [inlined]
#
#  [24] macro expansion
#
#     @ ~/.julia/packages/Metal/N2ABH/src/utilities.jl:10 [inlined]
#
#  [25] top-level scope
#
#     @ ~/src/LJ.jl/scratch/MetalPatterns/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W2sZmlsZQ==.jl:5

# %%
@device_code_typed @metal threads=threads,threads groups=groups,groups generate(simple, b)
# Out:
# InvalidIRError: compiling MethodInstance for generate(::typeof(simple), ::MtlDeviceMatrix{RGB{Float32}, 1}) resulted in invalid LLVM IR
#
# Reason: unsupported dynamic function invocation (call to _eltypes_supported(::Type{<:Colorant}, ::Type{C}) where C<:Colorant @ ColorTypes ~/.julia/packages/ColorTypes/L7biZ/src/traits.jl:150)
#
# Stacktrace:
#
#  [1] _eltypes_supported
#
#    @ ~/.julia/packages/ColorTypes/L7biZ/src/traits.jl:150
#
#  [2] eltypes_supported
#
#    @ ~/.julia/packages/ColorTypes/L7biZ/src/traits.jl:148
#
#  [3] issupported
#
#    @ ~/.julia/packages/ColorTypes/L7biZ/src/traits.jl:160
#
#  [4] ccolor
#
#    @ ~/.julia/packages/ColorTypes/L7biZ/src/traits.jl:450
#
#  [5] convert
#
#    @ ~/.julia/packages/ColorTypes/L7biZ/src/conversions.jl:72
#
#  [6] _new_colorant
#
#    @ ~/.julia/packages/ColorTypes/L7biZ/src/types.jl:558
#
#  [7] Color
#
#    @ ~/.julia/packages/ColorTypes/L7biZ/src/types.jl:535
#
#  [8] generate
#
#    @ ~/src/LJ.jl/scratch/MetalPatterns/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W1sZmlsZQ==.jl:8
#
# Reason: unsupported call to an unknown function (call to jl_f_issubtype)
#
# Stacktrace:
#
#  [1] issupported
#
#    @ ~/.julia/packages/ColorTypes/L7biZ/src/traits.jl:160
#
#  [2] ccolor
#
#    @ ~/.julia/packages/ColorTypes/L7biZ/src/traits.jl:450
#
#  [3] convert
#
#    @ ~/.julia/packages/ColorTypes/L7biZ/src/conversions.jl:72
#
#  [4] _new_colorant
#
#    @ ~/.julia/packages/ColorTypes/L7biZ/src/types.jl:558
#
#  [5] Color
#
#    @ ~/.julia/packages/ColorTypes/L7biZ/src/types.jl:535
#
#  [6] generate
#
#    @ ~/src/LJ.jl/scratch/MetalPatterns/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W1sZmlsZQ==.jl:8
#
# Hint: catch this exception as `err` and call `code_typed(err; interactive = true)` to introspect the erronous code with Cthulhu.jl
#
#
#
# Stacktrace:
#
#   [1] check_ir(job::GPUCompiler.CompilerJob{GPUCompiler.MetalCompilerTarget, Metal.MetalCompilerParams}, args::LLVM.Module)
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/1cGqD/src/validation.jl:167
#
#   [2] macro expansion
#
#     @ ~/.julia/packages/GPUCompiler/1cGqD/src/driver.jl:383 [inlined]
#
#   [3] macro expansion
#
#     @ ~/.julia/packages/Tracy/GcShf/src/tracepoint.jl:158 [inlined]
#
#   [4] macro expansion
#
#     @ ~/.julia/packages/GPUCompiler/1cGqD/src/driver.jl:382 [inlined]
#
#   [5] emit_llvm(job::GPUCompiler.CompilerJob; kwargs::@Kwargs{})
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/1cGqD/src/utils.jl:116
#
#   [6] emit_llvm(job::GPUCompiler.CompilerJob)
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/1cGqD/src/utils.jl:114
#
#   [7] compile_unhooked(output::Symbol, job::GPUCompiler.CompilerJob; kwargs::@Kwargs{})
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/1cGqD/src/driver.jl:95
#
#   [8] compile_unhooked
#
#     @ ~/.julia/packages/GPUCompiler/1cGqD/src/driver.jl:80 [inlined]
#
#   [9] compile(target::Symbol, job::GPUCompiler.CompilerJob; kwargs::@Kwargs{})
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/1cGqD/src/driver.jl:67
#
#  [10] compile
#
#     @ ~/.julia/packages/GPUCompiler/1cGqD/src/driver.jl:55 [inlined]
#
#  [11] (::Metal.var"#157#165"{GPUCompiler.CompilerJob{GPUCompiler.MetalCompilerTarget, Metal.MetalCompilerParams}})(ctx::LLVM.Context)
#
#     @ Metal ~/.julia/packages/Metal/N2ABH/src/compiler/compilation.jl:108
#
#  [12] JuliaContext(f::Metal.var"#157#165"{GPUCompiler.CompilerJob{GPUCompiler.MetalCompilerTarget, Metal.MetalCompilerParams}}; kwargs::@Kwargs{})
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/1cGqD/src/driver.jl:34
#
#  [13] JuliaContext(f::Function)
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/1cGqD/src/driver.jl:25
#
#  [14] macro expansion
#
#     @ ~/.julia/packages/Metal/N2ABH/src/compiler/compilation.jl:107 [inlined]
#
#  [15] macro expansion
#
#     @ ~/.julia/packages/ObjectiveC/TgrW6/src/os.jl:264 [inlined]
#
#  [16] compile(job::GPUCompiler.CompilerJob)
#
#     @ Metal ~/.julia/packages/Metal/N2ABH/src/compiler/compilation.jl:105
#
#  [17] actual_compilation(cache::Dict{Any, Any}, src::Core.MethodInstance, world::UInt64, cfg::GPUCompiler.CompilerConfig{GPUCompiler.MetalCompilerTarget, Metal.MetalCompilerParams}, compiler::typeof(Metal.compile), linker::typeof(Metal.link))
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/1cGqD/src/execution.jl:245
#
#  [18] cached_compilation(cache::Dict{Any, Any}, src::Core.MethodInstance, cfg::GPUCompiler.CompilerConfig{GPUCompiler.MetalCompilerTarget, Metal.MetalCompilerParams}, compiler::Function, linker::Function)
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/1cGqD/src/execution.jl:159
#
#  [19] macro expansion
#
#     @ ~/.julia/packages/Metal/N2ABH/src/compiler/execution.jl:189 [inlined]
#
#  [20] macro expansion
#
#     @ ./lock.jl:273 [inlined]
#
#  [21] mtlfunction(f::typeof(generate), tt::Type{Tuple{typeof(simple), MtlDeviceMatrix{RGB{Float32}, 1}}}; name::Nothing, kwargs::@Kwargs{})
#
#     @ Metal ~/.julia/packages/Metal/N2ABH/src/compiler/execution.jl:184
#
#  [22] mtlfunction(f::typeof(generate), tt::Type{Tuple{typeof(simple), MtlDeviceMatrix{RGB{Float32}, 1}}})
#
#     @ Metal ~/.julia/packages/Metal/N2ABH/src/compiler/execution.jl:182
#
#  [23] macro expansion
#
#     @ ~/.julia/packages/Metal/N2ABH/src/compiler/execution.jl:85 [inlined]
#
#  [24] macro expansion
#
#     @ ~/.julia/packages/GPUCompiler/1cGqD/src/reflection.jl:257 [inlined]
#
#  [25] top-level scope
#
#     @ ~/src/LJ.jl/scratch/MetalPatterns/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W3sZmlsZQ==.jl:1

# %%
function kernel(img)
    img[0] = eltype(img)(colorant"thistle")
    return 
end
# Out:
# kernel (generic function with 1 method)

# %%
@device_code_typed @metal kernel(MtlArray{RGB{Float32}}(undef, 1))
# Out:
# InvalidIRError: compiling MethodInstance for kernel(::MtlDeviceVector{RGB{Float32}, 1}) resulted in invalid LLVM IR
#
# Reason: unsupported dynamic function invocation (call to _eltypes_supported(::Type{<:Colorant}, ::Type{C}) where C<:Colorant @ ColorTypes ~/.julia/packages/ColorTypes/L7biZ/src/traits.jl:150)
#
# Stacktrace:
#
#  [1] _eltypes_supported
#
#    @ ~/.julia/packages/ColorTypes/L7biZ/src/traits.jl:150
#
#  [2] eltypes_supported
#
#    @ ~/.julia/packages/ColorTypes/L7biZ/src/traits.jl:148
#
#  [3] issupported
#
#    @ ~/.julia/packages/ColorTypes/L7biZ/src/traits.jl:160
#
#  [4] ccolor
#
#    @ ~/.julia/packages/ColorTypes/L7biZ/src/traits.jl:450
#
#  [5] convert
#
#    @ ~/.julia/packages/ColorTypes/L7biZ/src/conversions.jl:72
#
#  [6] _new_colorant
#
#    @ ~/.julia/packages/ColorTypes/L7biZ/src/types.jl:558
#
#  [7] Color
#
#    @ ~/.julia/packages/ColorTypes/L7biZ/src/types.jl:535
#
#  [8] kernel
#
#    @ ~/src/LJ.jl/scratch/MetalPatterns/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W4sZmlsZQ==.jl:2
#
# Reason: unsupported call to an unknown function (call to jl_f_issubtype)
#
# Stacktrace:
#
#  [1] issupported
#
#    @ ~/.julia/packages/ColorTypes/L7biZ/src/traits.jl:160
#
#  [2] ccolor
#
#    @ ~/.julia/packages/ColorTypes/L7biZ/src/traits.jl:450
#
#  [3] convert
#
#    @ ~/.julia/packages/ColorTypes/L7biZ/src/conversions.jl:72
#
#  [4] _new_colorant
#
#    @ ~/.julia/packages/ColorTypes/L7biZ/src/types.jl:558
#
#  [5] Color
#
#    @ ~/.julia/packages/ColorTypes/L7biZ/src/types.jl:535
#
#  [6] kernel
#
#    @ ~/src/LJ.jl/scratch/MetalPatterns/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W4sZmlsZQ==.jl:2
#
# Hint: catch this exception as `err` and call `code_typed(err; interactive = true)` to introspect the erronous code with Cthulhu.jl
#
#
#
# Stacktrace:
#
#   [1] check_ir(job::GPUCompiler.CompilerJob{GPUCompiler.MetalCompilerTarget, Metal.MetalCompilerParams}, args::LLVM.Module)
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/1cGqD/src/validation.jl:167
#
#   [2] macro expansion
#
#     @ ~/.julia/packages/GPUCompiler/1cGqD/src/driver.jl:383 [inlined]
#
#   [3] macro expansion
#
#     @ ~/.julia/packages/Tracy/GcShf/src/tracepoint.jl:158 [inlined]
#
#   [4] macro expansion
#
#     @ ~/.julia/packages/GPUCompiler/1cGqD/src/driver.jl:382 [inlined]
#
#   [5] emit_llvm(job::GPUCompiler.CompilerJob; kwargs::@Kwargs{})
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/1cGqD/src/utils.jl:116
#
#   [6] emit_llvm(job::GPUCompiler.CompilerJob)
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/1cGqD/src/utils.jl:114
#
#   [7] compile_unhooked(output::Symbol, job::GPUCompiler.CompilerJob; kwargs::@Kwargs{})
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/1cGqD/src/driver.jl:95
#
#   [8] compile_unhooked
#
#     @ ~/.julia/packages/GPUCompiler/1cGqD/src/driver.jl:80 [inlined]
#
#   [9] compile(target::Symbol, job::GPUCompiler.CompilerJob; kwargs::@Kwargs{})
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/1cGqD/src/driver.jl:67
#
#  [10] compile
#
#     @ ~/.julia/packages/GPUCompiler/1cGqD/src/driver.jl:55 [inlined]
#
#  [11] (::Metal.var"#157#165"{GPUCompiler.CompilerJob{GPUCompiler.MetalCompilerTarget, Metal.MetalCompilerParams}})(ctx::LLVM.Context)
#
#     @ Metal ~/.julia/packages/Metal/N2ABH/src/compiler/compilation.jl:108
#
#  [12] JuliaContext(f::Metal.var"#157#165"{GPUCompiler.CompilerJob{GPUCompiler.MetalCompilerTarget, Metal.MetalCompilerParams}}; kwargs::@Kwargs{})
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/1cGqD/src/driver.jl:34
#
#  [13] JuliaContext(f::Function)
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/1cGqD/src/driver.jl:25
#
#  [14] macro expansion
#
#     @ ~/.julia/packages/Metal/N2ABH/src/compiler/compilation.jl:107 [inlined]
#
#  [15] macro expansion
#
#     @ ~/.julia/packages/ObjectiveC/TgrW6/src/os.jl:264 [inlined]
#
#  [16] compile(job::GPUCompiler.CompilerJob)
#
#     @ Metal ~/.julia/packages/Metal/N2ABH/src/compiler/compilation.jl:105
#
#  [17] actual_compilation(cache::Dict{Any, Any}, src::Core.MethodInstance, world::UInt64, cfg::GPUCompiler.CompilerConfig{GPUCompiler.MetalCompilerTarget, Metal.MetalCompilerParams}, compiler::typeof(Metal.compile), linker::typeof(Metal.link))
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/1cGqD/src/execution.jl:245
#
#  [18] cached_compilation(cache::Dict{Any, Any}, src::Core.MethodInstance, cfg::GPUCompiler.CompilerConfig{GPUCompiler.MetalCompilerTarget, Metal.MetalCompilerParams}, compiler::Function, linker::Function)
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/1cGqD/src/execution.jl:159
#
#  [19] macro expansion
#
#     @ ~/.julia/packages/Metal/N2ABH/src/compiler/execution.jl:189 [inlined]
#
#  [20] macro expansion
#
#     @ ./lock.jl:273 [inlined]
#
#  [21] mtlfunction(f::typeof(kernel), tt::Type{Tuple{MtlDeviceVector{RGB{Float32}, 1}}}; name::Nothing, kwargs::@Kwargs{})
#
#     @ Metal ~/.julia/packages/Metal/N2ABH/src/compiler/execution.jl:184
#
#  [22] mtlfunction(f::typeof(kernel), tt::Type{Tuple{MtlDeviceVector{RGB{Float32}, 1}}})
#
#     @ Metal ~/.julia/packages/Metal/N2ABH/src/compiler/execution.jl:182
#
#  [23] macro expansion
#
#     @ ~/.julia/packages/Metal/N2ABH/src/compiler/execution.jl:85 [inlined]
#
#  [24] macro expansion
#
#     @ ~/.julia/packages/GPUCompiler/1cGqD/src/reflection.jl:257 [inlined]
#
#  [25] top-level scope
#
#     @ ~/src/LJ.jl/scratch/MetalPatterns/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W5sZmlsZQ==.jl:1
